# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_0326c38b209340b1be4ba7bd11760bb4 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='jVN2D1Fe41QeY-eD8mu8yRPDkbqpTxhYhOXGJiLHd8Fi',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

body = client_0326c38b209340b1be4ba7bd11760bb4.get_object(Bucket='realtimeairqualitymonitoring-donotdelete-pr-g1cel821do01uu',Key='city_day.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

d1 = pd.read_csv(body)
d1.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
body = client_0326c38b209340b1be4ba7bd11760bb4.get_object(Bucket='realtimeairqualitymonitoring-donotdelete-pr-g1cel821do01uu',Key='city_hour.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

d2 = pd.read_csv(body)
d2_dropped=d2.dropna()
d2_dropped.head()
# Out:
#             City             Datetime   PM2.5    PM10    NO    NO2    NOx  \
# 50888  Amaravati  2017-11-25 09:00:00  104.00  148.50  1.93  23.00  13.75
# 50889  Amaravati  2017-11-25 10:00:00   94.50  142.00  1.33  16.25   9.75
# 50890  Amaravati  2017-11-25 11:00:00   82.75  126.50  1.47  14.83   9.07
# 50893  Amaravati  2017-11-25 14:00:00   68.50  117.00  1.35  13.60   8.35
# 50894  Amaravati  2017-11-25 15:00:00   69.25  112.25  1.52  11.80   7.55
#
#         NH3   CO    SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 50888  9.80  0.1  15.30  117.62     0.30    10.40    0.23  155.0   Moderate
# 50889  9.65  0.1  17.00  136.23     0.28     7.10    0.15  159.0   Moderate
# 50890  9.70  0.1  15.40  149.92     0.20     4.55    0.08  173.0   Moderate
# 50893  7.40  0.1  21.80  161.70     0.10     2.30    0.00  191.0   Moderate
# 50894  9.25  0.1  21.38  161.68     0.10     2.35    0.00  191.0   Moderate

# %%
msk = np.random.rand(len(d2_dropped)) < 0.8
train = d2_dropped[msk]

test = d2_dropped[~msk]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(train[['AQI']])
regr.fit (x, y)
# Out:
# LinearRegression()

# %%
y1=regr.predict(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
x = np.asanyarray(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(test[['AQI']])

print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Variance score: 0.76
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
d1_dropped=d1.dropna()
d1_dropped.head()
# Out:
#            City        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 2123  Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2124  Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 2125  Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 2126  Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
# 2127  Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25  0.16
#
#         SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 2123  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2124  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 2125  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 2126  19.00  138.18     0.17     5.02    0.07  188.0   Moderate
# 2127  10.55  109.74     0.21     4.71    0.08  173.0   Moderate

# %%
msk2 = np.random.rand(len(d1_dropped)) < 0.8
train = d1_dropped[msk2]
test = d1_dropped[~msk2]

# %%
#regr = linear_model.LinearRegression()
x = np.asanyarray(train[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(train[['AQI']])
regr.fit (x, y)
# Out:
# LinearRegression()

# %%
y1=regr.predict(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
x = np.asanyarray(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(test[['AQI']])

print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Variance score: 0.92
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
body = client_0326c38b209340b1be4ba7bd11760bb4.get_object(Bucket='realtimeairqualitymonitoring-donotdelete-pr-g1cel821do01uu',Key='station_day.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

d30= pd.read_csv(body)
d3=d30.dropna()
d3.head()
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 1     AP001  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
# 5     AP001  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25  0.16
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate
# 5  10.55  109.74     0.21     4.71    0.08  173.0   Moderate

# %%
msk2 = np.random.rand(len(d3)) < 0.8
train = d3[msk2]
test = d3[~msk2]

# %%
#regr2 = linear_model.LinearRegression()
x = np.asanyarray(train[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(train[['AQI']])
regr.fit (x, y)
# Out:
# LinearRegression()

# %%
y1=regr.predict(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
x = np.asanyarray(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(test[['AQI']])

print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Variance score: 0.90
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
body = client_0326c38b209340b1be4ba7bd11760bb4.get_object(Bucket='realtimeairqualitymonitoring-donotdelete-pr-g1cel821do01uu',Key='station_hour.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

d40 = pd.read_csv(body)
d4=d40.dropna()
d4.head()
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    StationId             Datetime   PM2.5    PM10    NO    NO2    NOx   NH3  \
# 16     AP001  2017-11-25 09:00:00  104.00  148.50  1.93  23.00  13.75  9.80
# 17     AP001  2017-11-25 10:00:00   94.50  142.00  1.33  16.25   9.75  9.65
# 18     AP001  2017-11-25 11:00:00   82.75  126.50  1.47  14.83   9.07  9.70
# 21     AP001  2017-11-25 14:00:00   68.50  117.00  1.35  13.60   8.35  7.40
# 22     AP001  2017-11-25 15:00:00   69.25  112.25  1.52  11.80   7.55  9.25
#
#      CO    SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 16  0.1  15.30  117.62     0.30    10.40    0.23  155.0   Moderate
# 17  0.1  17.00  136.23     0.28     7.10    0.15  159.0   Moderate
# 18  0.1  15.40  149.92     0.20     4.55    0.08  173.0   Moderate
# ...

# %%
msk2 = np.random.rand(len(d4)) < 0.8
train = d4[msk2]
test = d4[~msk2]

# %%
#regr2 = linear_model.LinearRegression()
x = np.asanyarray(train[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(train[['AQI']])
regr.fit (x, y)
# Out:
# LinearRegression()

# %%
y1=regr.predict(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
x = np.asanyarray(test[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']])
y = np.asanyarray(test[['AQI']])

print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Variance score: 0.69
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
features=np.array([[81.40,124.50,1.44,20.50,12.08,10.72,0.12,15.24,127.09,0.20,6.50,0.06]])
prediction=regr.predict(features)
print("Prediction: {}".format(prediction))
# Out:
# Prediction: [[176.96492513]]
